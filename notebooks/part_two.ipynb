# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/cleaned_candidates.csv')

# %%
df['MaxRaisePer'] = df.groupby(['State', 'District'])['Raised'].transform(lambda x: x == x.max())
df = df.reset_index(level=0, drop=True)

# %%
df
# Out:
#      Unnamed: 0 State  District                 Name Party  Incumbent  Winner  \
# 0             0    AL         1           Jerry Carl     R      False    True
# 1             1    AL         1       James Averhart     D      False   False
# 2             2    AL         2          Barry Moore     R      False    True
# 3             3    AL         2  Phyllis Harvey-Hall     D      False   False
# 4             4    AL         3        Mike D Rogers     R       True    True
# ..          ...   ...       ...                  ...   ...        ...     ...
# 803         803    WI         7        Tricia Zunker     D      False   False
# 804         804    WI         8       Mike Gallagher     R       True    True
# 805         805    WI         8         Amanda Stuck     D      False   False
# 806         806    WY         1           Liz Cheney     R       True    True
# 807         807    WY         1   Lynnette Grey Bull     D      False   False
#
#      Vote Percentage     Raised      Spent  MaxRaisePer
# 0               64.9  1971321.0  1859349.0         True
# 1               35.0    80095.0    78973.0        False
# 2               65.3   650807.0   669368.0         True
# 3               34.6    56050.0    55988.0        False
# 4               67.5  1193111.0  1218564.0         True
# ..               ...        ...        ...          ...
# 803             39.2  1261957.0  1232690.0        False
# 804             64.0  3202905.0  2841801.0         True
# 805             36.0   416978.0   399916.0        False
# 806             68.6  3003883.0  3060167.0         True
# 807             24.6   134597.0   132235.0        False
#
# [808 rows x 11 columns]
